# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ### In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# **Objetives:**
# - Learn all about Data Science
# - List popular languages for Data Science
# - Learn about AI in Data Science
# - Learn Statistics

# %% [markdown]
# #### Some of the popular language that Data Sciencist use are:
# 1. R
# 2. C++
# 3. Python

# %% [markdown]
# #### Some of the commonly used libraries used by Data Sciencist include:
# 1. Pandas
# 2. Numpy
# 3. Plotly

# %% [markdown]
# | Data Sciencist Tools |
# | -------------------- |
# | R |
# | Python |
# | Jupyter |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %%
print ("This a simple arithmetic expression to mutiply then add integers")
(3*4)+5
# Out:
# This a simple arithmetic expression to mutiply then add integers
# 17

# %%
print ("This will convert 200 minutes to hours by diving by 60")
200/60
# Out:
# This will convert 200 minutes to hours by diving by 60
# 3.3333333333333335

# %% [markdown]
# ## Autor
# Jesus Ruiz Gutierrez
